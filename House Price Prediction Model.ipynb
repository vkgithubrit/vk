# %%
import os,sys,warnings
if not sys.warnoptions:    
    warnings.simplefilter('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("housing.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.shape
# Out:
# (20433, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
cate_val=[]
cont_val=[]
for column in df.columns:
    if df[column].nunique()<10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['ocean_proximity']

# %%
cont_val
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %%
df.nunique()
# Out:
# longitude               844
# latitude                861
# housing_median_age       52
# total_rooms            5911
# total_bedrooms         1923
# population             3879
# households             1809
# median_income         12825
# median_house_value     3833
# ocean_proximity           5
# dtype: int64

# %%
df.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY

# %%
df.hist(bins=20,figsize=(15,8))
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['median_house_value'],axis=1)
y=df['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
train_df=x_train.join(y_train)

# %%
train_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17727    -121.80     37.32                14.0       4412.0           924.0
# 2057     -119.63     36.64                33.0       1036.0           181.0
# 6453     -118.06     34.12                25.0       3891.0           848.0
# 4619     -118.31     34.07                28.0       2362.0           949.0
# 15266    -117.27     33.04                27.0       1839.0           392.0
# ...          ...       ...                 ...          ...             ...
# 11397    -117.97     33.72                24.0       2991.0           500.0
# 12081    -117.54     33.76                 5.0       5846.0          1035.0
# 5447     -118.42     34.01                42.0       1594.0           369.0
# 866      -122.04     37.57                12.0       5719.0          1064.0
# 15948    -122.43     37.73                52.0       3602.0           738.0
#
#        population  households  median_income ocean_proximity  \
# 17727      2698.0       891.0         4.7027       <1H OCEAN
# 2057        620.0       174.0         3.4107          INLAND
# 6453       1848.0       759.0         3.6639          INLAND
# 4619       2759.0       894.0         2.2364       <1H OCEAN
# 15266      1302.0       404.0         3.5500      NEAR OCEAN
# ...           ...         ...            ...             ...
# 11397      1437.0       453.0         5.4286       <1H OCEAN
# 12081      3258.0      1001.0         4.7965       <1H OCEAN
# 5447        952.0       362.0         3.0990       <1H OCEAN
# 866        3436.0      1057.0         5.2879        NEAR BAY
# 15948      2270.0       647.0         3.8934        NEAR BAY
#
#        median_house_value
# 17727            227600.0
# 2057             110400.0
# 6453             248100.0
# 4619             305600.0
# 15266            214600.0
# ...                   ...
# 11397            273400.0
# 12081            160800.0
# 5447             335400.0
# 866              231200.0
# 15948            251800.0
#
# [16346 rows x 10 columns]

# %%
train_df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Assuming 'ocean_proximity' is a categorical variable in your DataFrame
encoded_df = pd.get_dummies(train_df, columns=['ocean_proximity'])

# Now, 'ocean_proximity' has been one-hot encoded, you can compute the correlation matrix
correlation_matrix = encoded_df.corr()

# %%
correlation_matrix
# Out:
#                             longitude  latitude  housing_median_age  \
# longitude                    1.000000 -0.924340           -0.106111
# latitude                    -0.924340  1.000000            0.009535
# housing_median_age          -0.106111  0.009535            1.000000
# total_rooms                  0.040173 -0.033439           -0.359714
# total_bedrooms               0.066871 -0.066337           -0.319073
# population                   0.094641 -0.106192           -0.291689
# households                   0.054023 -0.071678           -0.301818
# median_income               -0.021911 -0.073213           -0.120550
# median_house_value          -0.048166 -0.141933            0.104041
# ocean_proximity_<1H OCEAN    0.318704 -0.445040            0.043953
# ocean_proximity_INLAND      -0.050463  0.347245           -0.235569
# ocean_proximity_ISLAND       0.008492 -0.014571            0.016215
# ocean_proximity_NEAR BAY    -0.475731  0.360561            0.255591
# ocean_proximity_NEAR OCEAN   0.046118 -0.161338            0.019654
#
#                             total_rooms  total_bedrooms  population  \
# longitude                      0.040173        0.066871    0.094641
# latitude                      -0.033439       -0.066337   -0.106192
# housing_median_age            -0.359714       -0.319073   -0.291689
# total_rooms                    1.000000        0.929102    0.851704
# total_bedrooms                 0.929102        1.000000    0.872241
# population                     0.851704        0.872241    1.000000
# households                     0.916829        0.978582    0.903093
# median_income                  0.202131       -0.005364    0.007224
# median_house_value             0.136040        0.051352   -0.023989
# ocean_proximity_<1H OCEAN     -0.004589        0.019935    0.073940
# ocean_proximity_INLAND         0.024758       -0.009414   -0.022369
# ocean_proximity_ISLAND        -0.005975       -0.002512   -0.008305
# ocean_proximity_NEAR BAY      -0.019720       -0.019040   -0.058497
# ocean_proximity_NEAR OCEAN    -0.008668        0.001575   -0.023004
#
#                             households  median_income  median_house_value  \
# longitude                     0.054023      -0.021911           -0.048166
# latitude                     -0.071678      -0.073213           -0.141933
# housing_median_age           -0.301818      -0.120550            0.104041
# total_rooms                   0.916829       0.202131            0.136040
# total_bedrooms                0.978582      -0.005364            0.051352
# population                    0.903093       0.007224           -0.023989
# households                    1.000000       0.016608            0.066598
# median_income                 0.016608       1.000000            0.688695
# median_house_value            0.066598       0.688695            1.000000
# ocean_proximity_<1H OCEAN     0.044033       0.163376            0.258017
# ocean_proximity_INLAND       -0.041926      -0.234058           -0.482445
# ocean_proximity_ISLAND       -0.006820      -0.009245            0.027272
# ocean_proximity_NEAR BAY     -0.009957       0.063391            0.158891
# ocean_proximity_NEAR OCEAN    0.002544       0.022947            0.135367
#
#                             ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# longitude                                    0.318704               -0.050463
# latitude                                    -0.445040                0.347245
# housing_median_age                           0.043953               -0.235569
# total_rooms                                 -0.004589                0.024758
# total_bedrooms                               0.019935               -0.009414
# population                                   0.073940               -0.022369
# households                                   0.044033               -0.041926
# median_income                                0.163376               -0.234058
# median_house_value                           0.258017               -0.482445
# ocean_proximity_<1H OCEAN                    1.000000               -0.604592
# ocean_proximity_INLAND                      -0.604592                1.000000
# ocean_proximity_ISLAND                      -0.012067               -0.009197
# ocean_proximity_NEAR BAY                    -0.317411               -0.241904
# ocean_proximity_NEAR OCEAN                  -0.343274               -0.261614
#
#                             ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# longitude                                 0.008492                 -0.475731
# latitude                                 -0.014571                  0.360561
# housing_median_age                        0.016215                  0.255591
# total_rooms                              -0.005975                 -0.019720
# total_bedrooms                           -0.002512                 -0.019040
# population                               -0.008305                 -0.058497
# households                               -0.006820                 -0.009957
# median_income                            -0.009245                  0.063391
# median_house_value                        0.027272                  0.158891
# ocean_proximity_<1H OCEAN                -0.012067                 -0.317411
# ocean_proximity_INLAND                   -0.009197                 -0.241904
# ocean_proximity_ISLAND                    1.000000                 -0.004828
# ocean_proximity_NEAR BAY                 -0.004828                  1.000000
# ocean_proximity_NEAR OCEAN               -0.005222                 -0.137347
#
#                             ocean_proximity_NEAR OCEAN
# longitude                                     0.046118
# latitude                                     -0.161338
# housing_median_age                            0.019654
# total_rooms                                  -0.008668
# total_bedrooms                                0.001575
# population                                   -0.023004
# households                                    0.002544
# median_income                                 0.022947
# median_house_value                            0.135367
# ocean_proximity_<1H OCEAN                    -0.343274
# ocean_proximity_INLAND                       -0.261614
# ocean_proximity_ISLAND                       -0.005222
# ocean_proximity_NEAR BAY                     -0.137347
# ocean_proximity_NEAR OCEAN                    1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(correlation_matrix,annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
train_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17727    -121.80     37.32                14.0       4412.0           924.0
# 2057     -119.63     36.64                33.0       1036.0           181.0
# 6453     -118.06     34.12                25.0       3891.0           848.0
# 4619     -118.31     34.07                28.0       2362.0           949.0
# 15266    -117.27     33.04                27.0       1839.0           392.0
# ...          ...       ...                 ...          ...             ...
# 11397    -117.97     33.72                24.0       2991.0           500.0
# 12081    -117.54     33.76                 5.0       5846.0          1035.0
# 5447     -118.42     34.01                42.0       1594.0           369.0
# 866      -122.04     37.57                12.0       5719.0          1064.0
# 15948    -122.43     37.73                52.0       3602.0           738.0
#
#        population  households  median_income ocean_proximity  \
# 17727      2698.0       891.0         4.7027       <1H OCEAN
# 2057        620.0       174.0         3.4107          INLAND
# 6453       1848.0       759.0         3.6639          INLAND
# 4619       2759.0       894.0         2.2364       <1H OCEAN
# 15266      1302.0       404.0         3.5500      NEAR OCEAN
# ...           ...         ...            ...             ...
# 11397      1437.0       453.0         5.4286       <1H OCEAN
# 12081      3258.0      1001.0         4.7965       <1H OCEAN
# 5447        952.0       362.0         3.0990       <1H OCEAN
# 866        3436.0      1057.0         5.2879        NEAR BAY
# 15948      2270.0       647.0         3.8934        NEAR BAY
#
#        median_house_value
# 17727            227600.0
# 2057             110400.0
# 6453             248100.0
# 4619             305600.0
# 15266            214600.0
# ...                   ...
# 11397            273400.0
# 12081            160800.0
# 5447             335400.0
# 866              231200.0
# 15948            251800.0
#
# [16346 rows x 10 columns]

# %%
train_df['total_rooms']=np.log(train_df['total_rooms']+1)
train_df['total_bedrooms']=np.log(train_df['total_bedrooms']+1)
train_df['population']=np.log(train_df['population']+1)
train_df['households']=np.log(train_df['households']+1)

# %%
train_df.hist(bins=10,figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_df=train_df.join(pd.get_dummies(train_df.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
custom_palette = "coolwarm"  # You can choose any Seaborn palette or a custom palette

sns.scatterplot(x=train_df['latitude'],y=train_df['longitude'],hue=train_df['median_house_value'], palette=custom_palette)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_df['bedroom_ratio']=train_df['total_bedrooms']/train_df['total_rooms']
train_df['household_rooms']=train_df['total_rooms']/train_df['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_df.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
x_train,y_train=train_df.drop(['median_house_value'],axis=1),train_df['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_df=x_test.join(y_test)
test_df['total_rooms']=np.log(test_df['total_rooms']+1)
test_df['total_bedrooms']=np.log(test_df['total_bedrooms']+1)
test_df['population']=np.log(test_df['population']+1)
test_df['households']=np.log(test_df['households']+1)

test_df=test_df.join(pd.get_dummies(test_df.ocean_proximity)).drop(['ocean_proximity'],axis=1)

test_df['bedroom_ratio']=test_df['total_bedrooms']/test_df['total_rooms']
test_df['household_rooms']=test_df['total_rooms']/test_df['households']

x_test,y_test=test_df.drop(['median_house_value'],axis=1),test_df['median_house_value']

# %%
test_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14416    -117.24     32.79                20.0     6.869014        5.631212
# 16383    -121.29     38.01                 2.0     8.764678        7.018402
# 7731     -118.14     33.92                31.0     8.224700        6.749931
# 1410     -122.07     37.94                30.0     7.139660        5.624018
# 1335     -121.89     37.99                 4.0     7.683404        6.393591
# ...          ...       ...                 ...          ...             ...
# 8291     -118.15     33.76                36.0     7.978311        6.666957
# 6274     -117.95     34.03                33.0     7.486053        5.978886
# 2997     -119.03     35.32                12.0     7.909122        6.309918
# 13440    -117.42     34.08                28.0     7.741099        6.040255
# 14797    -117.10     32.57                14.0     8.528924        7.170120
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 14416    6.265301    5.541264         3.1838            245800.0      False
# 16383    8.110127    6.864848         4.4871            137900.0      False
# 7731     7.746733    6.687109         3.2237            218200.0       True
# 1410     6.562444    5.402677         2.8920            220800.0      False
# 1335     6.834109    6.135565         4.1016            170500.0      False
# ...           ...         ...            ...                 ...        ...
# 8291     7.076654    6.620073         3.5985            500001.0      False
# 6274     7.325149    5.932245         3.3389            157900.0       True
# 2997     7.166266    6.261492         2.5575            100200.0      False
# 13440    7.180070    6.098074         3.4844            127700.0      False
# 14797    8.206038    7.085064         2.3253            133700.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 14416   False   False     False        True       0.819799         1.239612
# 16383    True   False     False       False       0.800760         1.276748
# 7731    False   False     False       False       0.820690         1.229934
# 1410    False   False      True       False       0.787715         1.321504
# 1335     True   False     False       False       0.832130         1.252273
# ...       ...     ...       ...         ...            ...              ...
# 8291    False   False     False        True       0.835635         1.205170
# 6274    False   False     False       False       0.798670         1.261926
# 2997     True   False     False       False       0.797803         1.263137
# 13440    True   False     False       False       0.780284         1.269433
# 14797   False   False     False        True       0.840683         1.203789
#
# [4087 rows x 16 columns]

# %%
lin.score(x_test,y_test)
# Out:
# 0.6687407117584971

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(x_test,y_test)
# Out:
# 0.8216878587589773

# %%
from sklearn.model_selection import GridSearchCV
rf=RandomForestRegressor()
param_grid={
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8],
    
}
grid_search=GridSearchCV(rf,param_grid,cv=5,
                        scoring="neg_mean_squared_error",
                        return_train_score=True)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_rf=grid_search.best_estimator_

# %%
best_rf.score(x_test,y_test)
# Out:
# 0.8179904637988936

# %% [markdown]
# # Thank You!
